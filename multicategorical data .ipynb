# %%
# standard modules we will always use
import pandas as pd
import numpy as np
import scipy as sp
import mglearn
from IPython.display import display
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv("redwine.csv")
#display(data)

# %%
X = data.drop(columns =['quality'])
Y = data['quality']

# %%
from sklearn.svm import LinearSVC as svc

# %%
linear_svm = svc().fit(X,Y)
print('Coefficient shape:', linear_svm.coef_.shape)
print('Intercept shape:', linear_svm.intercept_.shape)


#print('Training set score: {:.3f}'.format(linear_svm.score()))
# Out:
# Coefficient shape: (6, 11)
# Intercept shape: (6,)
# /home/adir/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)

# %% [markdown]
# Above we see that there are 6 classes and 11 features and each row contains the coefficient vector for each class and
# each column contains the coefficient value for a specific feature.  The intercept is a vector ( 1d array) holding the
# intercepts for each class.

# %%
res = pd.scatter_matrix(X, c=Y, figsize = (20,20), marker ='v',
                       hist_kwds={'bins': 20}, s = 60, alpha = .8, cmap=mglearn.cm3)
# Out:
# /home/adir/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: pandas.scatter_matrix is deprecated, use pandas.plotting.scatter_matrix instead

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
mglearn.discrete_scatter(X.iloc[:,0].values,X.iloc[:,1].values, X.iloc[:,2].values, Y.values)
plt.xlabel("feature 0")
plt.ylabel('feature 1')
plt.zlabel('feature 2')
plt.legend(['Class 0', 'class 1','class 2','class 3', 'class 4', 'class 5'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-3fdc57e66eff> in <module>
#       2 plt.xlabel("feature 0")
#       3 plt.ylabel('feature 1')
# ----> 4 plt.zlabel('feature 2')
#       5 plt.legend(['Class 0', 'class 1','class 2','class 3', 'class 4', 'class 5'])
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'zlabel'

# %%
# just playing with three deminsional plots  

fig = plt.figure(figsize=(10,8))
ax = plt.subplot(111, projection='3d')
markers = ['o', '^', 'v', 'D', 's', '*', 'p', 'h', 'H', '8', '<', '>']
ax.scatter(X.iloc[:,0].values, X.iloc[:,1].values, X.iloc[:,2].values)

for i in range(6):
    ax.scatter(X.iloc[:,0].values, X.iloc[:,1].values, X.iloc[:,2].values, s=100,
             edgecolors='black', marker=markers[i])

plt.legend(bbox_to_anchor=(1.2,0.7))
ax.set_xlabel('F1')
ax.set_ylabel('F2')
ax.set_zlabel('F3')
ax.set_title("Wine Quality ", fontdict={'fontsize': 15}, loc='center')
plt.show()
# Out:
# No handles with labels found to put in legend.
